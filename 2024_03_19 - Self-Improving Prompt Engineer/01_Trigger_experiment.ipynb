# %% [markdown]
# ### Notebook setup

# %%
# %pip install openai==1.12.0 langchain==0.1.12 langchain_openai==0.0.5 arize-phoenix langchain-anthropic==0.1.4

# %%
from dotenv import load_dotenv
import os

# Load .env file
load_dotenv('../.env')

# Set model variables
OPENAI_BASE_URL = "https://api.openai.com/v1"
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
OPENAI_ORGANIZATION = os.getenv("OPENAI_ORGANIZATION")

# ANTHROPIC_API_KEY = os.getenv("ANTHROPIC_API_KEY")

# TOGETHER_BASE_URL = "https://api.together.xyz"
# TOGETHER_API_KEY = os.getenv("TOGETHER_API_KEY")

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_PROJECT"] = "Prototypes"

# %% [markdown]
# ### Define the initial values we will iterate on

# %%
OPENER = """
You are a supervisor managing a team of knowledge eperts.

Your team's job is to create a perfect knowledge base about a family's dining habits to assist in highly customized meal planning.
"""

INSTRUCTIONS = """
The knowledge base should ultimately consist of many discrete pieces of information that add up to a rich persona (e.g. I like pasta; I am allergic to shellfish; I don't eat mussels; I live in Austin, Texas; I have a husband and 2 children aged 5 and 7).

Every time you receive a message, you will evaluate if it has any information worth recording in the knowledge base.

A message may contain multiple pieces of information. When that occurs, identify and save all the information as separate pieces of knowledge.

You are only interested in the following categories of information:

1. The family's food allergies (for example: a dairy or soy allergy) - These are important to know because they can be life-threatening. Only log something as an allergy if you are CERTAIN it is an allergy and not just a dislike.
2. Foods the family likes (for example: likes pasta) - These are important to know because they can help you plan meals, but are not life-threatening allergies.
3. Foods the family dislikes (for example: doesn't eat mussels or rarely eats beef) - These are important to know because they can help you plan meals, but are not life-threatening.
4. Attributes about the family that may impact weekly meal planning (for example: lives in Austin, has a husband and 2 children, has a garden, likes big lunches, etc.)
"""

CHAIN_OF_THOUGHT = """
When you receive a message, you perform a sequence of steps consisting of:

1. Analyze the most recent Human message for information. You will see multiple messages for context, but we are only looking for new information in the most recent message.
2. Compare this to the knowledge you already have.
3. Determine if this is new knowledge, an update to old knowledge that now needs to change, or should result in deleting information that is not correct. It's possible that a food you previously wrote as a dislike might now be a like, or that a family member who previously liked a food now dislikes it - those examples would require an update.
"""

CLOSER = """
I will tip you $20 if you are perfect, and I will fine you $40 if you miss any important information or change any incorrect information.
"""

# %% [markdown]
# ### Test the prompt writer graph

# %%
from graphs import prompt_writer_graph
import importlib

importlib.invalidate_caches()
importlib.reload(prompt_writer_graph)
from graphs.prompt_writer_graph import app

input = {
    "prompt": {
        "opener": OPENER,
        "instructions": INSTRUCTIONS,
        "chain_of_thought": CHAIN_OF_THOUGHT,
        "closer": CLOSER,
    },
    "messages": [],
}

for output in app.with_config(
    {"run_name": "Prompt Writer - Test Agent", "recursion_limit": 100}
).stream(input):
    # stream() yields dictionaries with output keyed by node name
    for key, value in output.items():
        print(f"Output from node '{key}':")
        print("---")
        print(value)
    print("\n---\n")
# Out:
# Output from node 'prompt_controller':
# ---
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_nCQNKHwlh5VUKnVogo3qrzzC', 'function': {'arguments': '{}', 'name': 'Prompt_Writer'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls'})]}
#
# ---
#
# Output from node 'action':
# ---
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_nCQNKHwlh5VUKnVogo3qrzzC', 'function': {'arguments': '{}', 'name': 'Prompt_Writer'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls'}), ToolMessage(content='New prompt written.', name='Prompt_Writer', tool_call_id='call_nCQNKHwlh5VUKnVogo3qrzzC')], 'prompt_change_log': [{'what_changed': 'instructions', 'previous_value': "\nThe knowledge base should ultimately consist of many discrete pieces of information that add up to a rich persona (e.g. I like pasta; I am allergic to shellfish; I don't eat mussels; I live in Austin, Texas; I have a husband and 2 children aged 5 and 7).\n\nEvery time you receive a message, you will evaluate if it has any information worth recording in the knowledge base.\n\nA message may contain multiple pieces of information. When that occurs, identify and save all the information as separate pieces of knowledge.\n\nYou are only interested in the following categories of information:\n\n1. The family's food allergies (for example: a dairy or soy allergy) - These are important to know because they can be life-threatening. Only log something as an allergy if you are CERTAIN it is an allergy and not just a dislike.\n2. Foods the family likes (for example: likes pasta) - These are important to know because they can help you plan meals, but are not life-threatening allergies.\n3. Foods the family dislikes (for example: doesn't eat mussels or rarely eats beef) - These are important to know because they can help you plan meals, but are not life-threatening.\n4. Attributes about the family that may impact weekly meal planning (for example: lives in Austin, has a husband and 2 children, has a garden, likes big lunches, etc.)\n", 'new_value': "The knowledge base should capture all relevant details about a family's dining habits to facilitate personalized meal planning. It should include information such as food allergies (e.g. dairy, soy), food preferences (e.g. likes pasta), and lifestyle attributes that impact meal choices (e.g. has a garden, likes big lunches). When processing a message, focus on extracting and recording only the essential information related to the family's eating habits.", 'results': '', 'decision': 'Discarded change', 'accuracy': 0.0}]}
#
# ---
#
# ----------------
# Testing the new prompt with the change:
# What changed: instructions
# New value: The knowledge base should capture all relevant details about a family's dining habits to facilitate personalized meal planning. It should include information such as food allergies (e.g. dairy, soy), food preferences (e.g. likes pasta), and lifestyle attributes that impact meal choices (e.g. has a garden, likes big lunches). When processing a message, focus on extracting and recording only the essential information related to the family's eating habits.
# Running line 1
# Expected Output Result:  False Failed at Knowledge: the agent incorrectly identified 'I am not a pescatarian' instead of 'I am a pescatarian'
# Bad Output Result:  DIFFERENT
# Running line 2
# Expected Output Result:  True
# Bad Output Result:  DIFFERENT
# Running line 3
# Expected Output Result:  False Failed at Knowledge: did not include 'Family likes trying new exotic fruits every week'
# Bad Output Result:  DIFFERENT
# Running line 4
# Expected Output Result:  False Failed at Knowledge: The actual response includes additional information about including seafood in the diet, which was not present in the expected response.
# Bad Output Result:  DIFFERENT
# Encountered 3 bad responses. Ending process.
# {'TP': 1, 'FP': 0, 'TN': 4, 'FN': 3}
# Accuracy:  0.625
# Test complete. Accuracy: 0.625
# {'TP': 1, 'FP': 0, 'TN': 4, 'FN': 3}
# Accepted change, here is the new prompt:
# {'opener': "\nYou are a supervisor managing a team of knowledge eperts.\n\nYour team's job is to create a perfect knowledge base about a family's dining habits to assist in highly customized meal planning.\n", 'instructions': "The knowledge base should capture all relevant details about a family's dining habits to facilitate personalized meal planning. It should include information such as food allergies (e.g. dairy, soy), food preferences (e.g. likes pasta), and lifestyle attributes that impact meal choices (e.g. has a garden, likes big lunches). When processing a message, focus on extracting and recording only the essential information related to the family's eating habits.", 'chain_of_thought': "\nWhen you receive a message, you perform a sequence of steps consisting of:\n\n1. Analyze the most recent Human message for information. You will see multiple messages for context, but we are only looking for new information in the most recent message.\n2. Compare this to the knowledge you already have.\n3. Determine if this is new knowledge, an update to old knowledge that now needs to change, or should result in deleting information that is not correct. It's possible that a food you previously wrote as a dislike might now be a like, or that a family member who previously liked a food now dislikes it - those examples would require an update.\n", 'closer': '\nI will tip you $20 if you are perfect, and I will fine you $40 if you miss any important information or change any incorrect information.\n'}
# Output from node 'test':
# ---
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_nCQNKHwlh5VUKnVogo3qrzzC', 'function': {'arguments': '{}', 'name': 'Prompt_Writer'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls'}), ToolMessage(content='New prompt written.', name='Prompt_Writer', tool_call_id='call_nCQNKHwlh5VUKnVogo3qrzzC'), FunctionMessage(content='Tested the new prompt. It had an accuracy of 0.625', name='Tester')], 'prompt': {'opener': "\nYou are a supervisor managing a team of knowledge eperts.\n\nYour team's job is to create a perfect knowledge base about a family's dining habits to assist in highly customized meal planning.\n", 'instructions': "The knowledge base should capture all relevant details about a family's dining habits to facilitate personalized meal planning. It should include information such as food allergies (e.g. dairy, soy), food preferences (e.g. likes pasta), and lifestyle attributes that impact meal choices (e.g. has a garden, likes big lunches). When processing a message, focus on extracting and recording only the essential information related to the family's eating habits.", 'chain_of_thought': "\nWhen you receive a message, you perform a sequence of steps consisting of:\n\n1. Analyze the most recent Human message for information. You will see multiple messages for context, but we are only looking for new information in the most recent message.\n2. Compare this to the knowledge you already have.\n3. Determine if this is new knowledge, an update to old knowledge that now needs to change, or should result in deleting information that is not correct. It's possible that a food you previously wrote as a dislike might now be a like, or that a family member who previously liked a food now dislikes it - those examples would require an update.\n", 'closer': '\nI will tip you $20 if you are perfect, and I will fine you $40 if you miss any important information or change any incorrect information.\n'}, 'prompt_change_log': [{'what_changed': 'instructions', 'previous_value': "\nThe knowledge base should ultimately consist of many discrete pieces of information that add up to a rich persona (e.g. I like pasta; I am allergic to shellfish; I don't eat mussels; I live in Austin, Texas; I have a husband and 2 children aged 5 and 7).\n\nEvery time you receive a message, you will evaluate if it has any information worth recording in the knowledge base.\n\nA message may contain multiple pieces of information. When that occurs, identify and save all the information as separate pieces of knowledge.\n\nYou are only interested in the following categories of information:\n\n1. The family's food allergies (for example: a dairy or soy allergy) - These are important to know because they can be life-threatening. Only log something as an allergy if you are CERTAIN it is an allergy and not just a dislike.\n2. Foods the family likes (for example: likes pasta) - These are important to know because they can help you plan meals, but are not life-threatening allergies.\n3. Foods the family dislikes (for example: doesn't eat mussels or rarely eats beef) - These are important to know because they can help you plan meals, but are not life-threatening.\n4. Attributes about the family that may impact weekly meal planning (for example: lives in Austin, has a husband and 2 children, has a garden, likes big lunches, etc.)\n", 'new_value': "The knowledge base should capture all relevant details about a family's dining habits to facilitate personalized meal planning. It should include information such as food allergies (e.g. dairy, soy), food preferences (e.g. likes pasta), and lifestyle attributes that impact meal choices (e.g. has a garden, likes big lunches). When processing a message, focus on extracting and recording only the essential information related to the family's eating habits.", 'results': [{'input': "I'm a pescatarian, so I don't eat meat but I do eat seafood.", 'evaluation_result': "Failed  ...
#
# ---
#
# Output from node 'prompt_controller':
# ---
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_nCQNKHwlh5VUKnVogo3qrzzC', 'function': {'arguments': '{}', 'name': 'Prompt_Writer'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls'}), ToolMessage(content='New prompt written.', name='Prompt_Writer', tool_call_id='call_nCQNKHwlh5VUKnVogo3qrzzC'), FunctionMessage(content='Tested the new prompt. It had an accuracy of 0.625', name='Tester'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_7njzPhs0HP4TJXz3gWYXhyIx', 'function': {'arguments': '{}', 'name': 'Prompt_Writer'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls'})]}
#
# ---
#
# Output from node 'action':
# ---
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_nCQNKHwlh5VUKnVogo3qrzzC', 'function': {'arguments': '{}', 'name': 'Prompt_Writer'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls'}), ToolMessage(content='New prompt written.', name='Prompt_Writer', tool_call_id='call_nCQNKHwlh5VUKnVogo3qrzzC'), FunctionMessage(content='Tested the new prompt. It had an accuracy of 0.625', name='Tester'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_7njzPhs0HP4TJXz3gWYXhyIx', 'function': {'arguments': '{}', 'name': 'Prompt_Writer'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls'}), ToolMessage(content='New prompt written.', name='Prompt_Writer', tool_call_id='call_7njzPhs0HP4TJXz3gWYXhyIx')], 'prompt_change_log': [{'what_changed': 'instructions', 'previous_value': "\nThe knowledge base should ultimately consist of many discrete pieces of information that add up to a rich persona (e.g. I like pasta; I am allergic to shellfish; I don't eat mussels; I live in Austin, Texas; I have a husband and 2 children aged 5 and 7).\n\nEvery time you receive a message, you will evaluate if it has any information worth recording in the knowledge base.\n\nA message may contain multiple pieces of information. When that occurs, identify and save all the information as separate pieces of knowledge.\n\nYou are only interested in the following categories of information:\n\n1. The family's food allergies (for example: a dairy or soy allergy) - These are important to know because they can be life-threatening. Only log something as an allergy if you are CERTAIN it is an allergy and not just a dislike.\n2. Foods the family likes (for example: likes pasta) - These are important to know because they can help you plan meals, but are not life-threatening allergies.\n3. Foods the family dislikes (for example: doesn't eat mussels or rarely eats beef) - These are important to know because they can help you plan meals, but are not life-threatening.\n4. Attributes about the family that may impact weekly meal planning (for example: lives in Austin, has a husband and 2 children, has a garden, likes big lunches, etc.)\n", 'new_value': "The knowledge base should capture all relevant details about a family's dining habits to facilitate personalized meal planning. It should include information such as food allergies (e.g. dairy, soy), food preferences (e.g. likes pasta), and lifestyle attributes that impact meal choices (e.g. has a garden, likes big lunches). When processing a message, focus on extracting and recording only the essential information related to the family's eating habits.", 'results': [{'input': "I'm a pescatarian, so I don't eat meat but I do eat seafood.", 'evaluation_result': "Failed at Knowledge: the agent incorrectly identified 'I am not a pescatarian' instead of 'I am a pescatarian'"}, {'input': 'I love trying new exotic fruits every week to mix things up.', 'evaluation_result': "Failed at Knowledge: did not include 'Family likes trying new exotic fruits every week'"}, {'input': "I'm a pescatarian, so I don't eat meat but I do include seafood in my diet.", 'evaluation_result': 'Failed at Knowledge: The actual response includes additional information about including seafood in the diet, which was not present in the expected response.'}], 'decision': 'Accepted change', 'accuracy': 0.625}, {'what_changed': 'instructions', 'previous_value': "The knowledge base should capture all relevant details about a family's dining habits to facilitate personalized meal planning. It should include information such as food allergies (e.g. dairy, soy), food preferences (e.g. likes pasta), and lifestyle attributes that impact meal choices (e.g. has a garden, likes big lunches). When processing a message, focus on extracting and recording only the essential information related to the family's eating habits.", 'new_value': "The knowledge base should capture ...
#
# ---
#
# ----------------
# Testing the new prompt with the change:
# What changed: instructions
# New value: The knowledge base should capture all relevant details about a family's dining habits to facilitate personalized meal planning. It should include information such as food allergies (e.g. dairy, soy), food preferences (e.g. likes pasta), lifestyle attributes that impact meal choices (e.g. has a garden, likes big lunches), and specific family member details (e.g. ages of children, dietary preferences). When processing a message, focus on extracting and recording only the essential information related to the family's eating habits.
# Running line 1
# Expected Output Result:  False Failed at Knowledge: the agent incorrectly identified 'I am not a pescatarian' instead of 'I am a pescatarian'
# Bad Output Result:  DIFFERENT
# Running line 2
# Expected Output Result:  True
# Bad Output Result:  DIFFERENT
# Running line 3
# Expected Output Result:  False Failed at Knowledge: The actual response only mentions 'Exotic fruits' instead of 'Family likes trying new exotic fruits every week'
# Bad Output Result:  DIFFERENT
# Running line 4
# Expected Output Result:  False Failed at Knowledge: The actual response includes additional information about including seafood in the diet, which was not present in the expected response.
# Bad Output Result:  DIFFERENT
# Encountered 3 bad responses. Ending process.
# {'TP': 1, 'FP': 0, 'TN': 4, 'FN': 3}
# Accuracy:  0.625
# Test complete. Accuracy: 0.625
# {'TP': 1, 'FP': 0, 'TN': 4, 'FN': 3}
# Rejected change
# Output from node 'test':
# ---
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_nCQNKHwlh5VUKnVogo3qrzzC', 'function': {'arguments': '{}', 'name': 'Prompt_Writer'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls'}), ToolMessage(content='New prompt written.', name='Prompt_Writer', tool_call_id='call_nCQNKHwlh5VUKnVogo3qrzzC'), FunctionMessage(content='Tested the new prompt. It had an accuracy of 0.625', name='Tester'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_7njzPhs0HP4TJXz3gWYXhyIx', 'function': {'arguments': '{}', 'name': 'Prompt_Writer'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls'}), ToolMessage(content='New prompt written.', name='Prompt_Writer', tool_call_id='call_7njzPhs0HP4TJXz3gWYXhyIx'), FunctionMessage(content='Tested the new prompt. It had an accuracy of 0.625', name='Tester')], 'prompt': {'opener': "\nYou are a supervisor managing a team of knowledge eperts.\n\nYour team's job is to create a perfect knowledge base about a family's dining habits to assist in highly customized meal planning.\n", 'instructions': "The knowledge base should capture all relevant details about a family's dining habits to facilitate personalized meal planning. It should include information such as food allergies (e.g. dairy, soy), food preferences (e.g. likes pasta), and lifestyle attributes that impact meal choices (e.g. has a garden, likes big lunches). When processing a message, focus on extracting and recording only the essential information related to the family's eating habits.", 'chain_of_thought': "\nWhen you receive a message, you perform a sequence of steps consisting of:\n\n1. Analyze the most recent Human message for information. You will see multiple messages for context, but we are only looking for new information in the most recent message.\n2. Compare this to the knowledge you already have.\n3. Determine if this is new knowledge, an update to old knowledge that now needs to change, or should result in deleting information that is not correct. It's possible that a food you previously wrote as a dislike might now be a like, or that a family member who previously liked a food now dislikes it - those examples would require an update.\n", 'closer': '\nI will tip you $20 if you are perfect, and I will fine you $40 if you miss any important information or change any incorrect information.\n'}, 'prompt_change_log': [{'what_changed': 'instructions', 'previous_value': "\nThe knowledge base should ultimately consist of many discrete pieces of information that add up to a rich persona (e.g. I like pasta; I am allergic to shellfish; I don't eat mussels; I live in Austin, Texas; I have a husband and 2 children aged 5 and 7).\n\nEvery time you receive a message, you will evaluate if it has any information worth recording in the knowledge base.\n\nA message may contain multiple pieces of information. When that occurs, identify and save all the information as separate pieces of knowledge.\n\nYou are only interested in the following categories of information:\n\n1. The family's food allergies (for example: a dairy or soy allergy) - These are important to know because they can be life-threatening. Only log something as an allergy if you are CERTAIN it is an allergy and not just a dislike.\n2. Foods the family likes (for example: likes pasta) - These are important to know because they can help you plan meals, but are not life-threatening allergies.\n3. Foods the family dislikes (for example: doesn't eat mussels or rarely eats beef) - These are important to know because they can help you plan meals, but are not life-threatening.\n4. Attributes about the family that may impact weekly meal planning (for example: lives in Austin, has a husband and 2 children, has a garden, likes big lunches, etc.)\n", 'new_value': "The knowledge base should capture all relevant details about a family's dining habits to facilitate personalized meal planning.  ...
#
# ---
#
# Output from node 'prompt_controller':
# ---
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_nCQNKHwlh5VUKnVogo3qrzzC', 'function': {'arguments': '{}', 'name': 'Prompt_Writer'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls'}), ToolMessage(content='New prompt written.', name='Prompt_Writer', tool_call_id='call_nCQNKHwlh5VUKnVogo3qrzzC'), FunctionMessage(content='Tested the new prompt. It had an accuracy of 0.625', name='Tester'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_7njzPhs0HP4TJXz3gWYXhyIx', 'function': {'arguments': '{}', 'name': 'Prompt_Writer'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls'}), ToolMessage(content='New prompt written.', name='Prompt_Writer', tool_call_id='call_7njzPhs0HP4TJXz3gWYXhyIx'), FunctionMessage(content='Tested the new prompt. It had an accuracy of 0.625', name='Tester'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_nA0wNeObDiQpzhwVI1TJGdeJ', 'function': {'arguments': '{}', 'name': 'Prompt_Writer'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls'})]}
#
# ---
#
# Output from node 'action':
# ---
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_nCQNKHwlh5VUKnVogo3qrzzC', 'function': {'arguments': '{}', 'name': 'Prompt_Writer'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls'}), ToolMessage(content='New prompt written.', name='Prompt_Writer', tool_call_id='call_nCQNKHwlh5VUKnVogo3qrzzC'), FunctionMessage(content='Tested the new prompt. It had an accuracy of 0.625', name='Tester'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_7njzPhs0HP4TJXz3gWYXhyIx', 'function': {'arguments': '{}', 'name': 'Prompt_Writer'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls'}), ToolMessage(content='New prompt written.', name='Prompt_Writer', tool_call_id='call_7njzPhs0HP4TJXz3gWYXhyIx'), FunctionMessage(content='Tested the new prompt. It had an accuracy of 0.625', name='Tester'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_nA0wNeObDiQpzhwVI1TJGdeJ', 'function': {'arguments': '{}', 'name': 'Prompt_Writer'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls'}), ToolMessage(content='New prompt written.', name='Prompt_Writer', tool_call_id='call_nA0wNeObDiQpzhwVI1TJGdeJ')], 'prompt_change_log': [{'what_changed': 'instructions', 'previous_value': "\nThe knowledge base should ultimately consist of many discrete pieces of information that add up to a rich persona (e.g. I like pasta; I am allergic to shellfish; I don't eat mussels; I live in Austin, Texas; I have a husband and 2 children aged 5 and 7).\n\nEvery time you receive a message, you will evaluate if it has any information worth recording in the knowledge base.\n\nA message may contain multiple pieces of information. When that occurs, identify and save all the information as separate pieces of knowledge.\n\nYou are only interested in the following categories of information:\n\n1. The family's food allergies (for example: a dairy or soy allergy) - These are important to know because they can be life-threatening. Only log something as an allergy if you are CERTAIN it is an allergy and not just a dislike.\n2. Foods the family likes (for example: likes pasta) - These are important to know because they can help you plan meals, but are not life-threatening allergies.\n3. Foods the family dislikes (for example: doesn't eat mussels or rarely eats beef) - These are important to know because they can help you plan meals, but are not life-threatening.\n4. Attributes about the family that may impact weekly meal planning (for example: lives in Austin, has a husband and 2 children, has a garden, likes big lunches, etc.)\n", 'new_value': "The knowledge base should capture all relevant details about a family's dining habits to facilitate personalized meal planning. It should include information such as food allergies (e.g. dairy, soy), food preferences (e.g. likes pasta), and lifestyle attributes that impact meal choices (e.g. has a garden, likes big lunches). When processing a message, focus on extracting and recording only the essential information related to the family's eating habits.", 'results': [{'input': "I'm a pescatarian, so I don't eat meat but I do eat seafood.", 'evaluation_result': "Failed at Knowledge: the agent incorrectly identified 'I am not a pescatarian' instead of 'I am a pescatarian'"}, {'input': 'I love trying new exotic fruits every week to mix things up.', 'evaluation_result': "Failed at Knowledge: did not include 'Family likes trying new exotic fruits every week'"}, {'input': "I'm a pescatarian, so I don't eat meat but I do include seafood in my diet.", 'evaluation_result': 'Failed at Knowledge: The actual response includes additional information about including seafood in the diet, which was not present in the expected response.'}], 'decision': 'Accepted change', 'accuracy': 0.625}, {'what_changed': 'instructions', 'previous_value': "The knowledge base should capture all relevant details about ...
#
# ---
#
# ----------------
# Testing the new prompt with the change:
# What changed: instructions
# New value: The knowledge base should encompass all relevant details about a family's dining habits to enable personalized meal planning. It should include information such as food allergies (e.g. dairy, soy), food preferences (e.g. likes pasta), lifestyle attributes impacting meal choices (e.g. has a garden, likes big lunches), specific family member details (e.g. ages of children, dietary preferences), and any recent changes in preferences or allergies. When processing a message, focus on extracting and recording only the essential and up-to-date information related to the family's eating habits.
# Running line 1
# Expected Output Result:  False Failed at Knowledge: the agent incorrectly identified 'I am not a pescatarian' instead of 'I am a pescatarian'
# Bad Output Result:  DIFFERENT
# Running line 2
# Expected Output Result:  True
# Bad Output Result:  DIFFERENT
# Running line 3
# Expected Output Result:  False Failed at Knowledge: did not correctly identify 'Family likes trying new exotic fruits every week' as the new knowledge
# Bad Output Result:  DIFFERENT.
#
# 1. The actual response correctly identifies the new knowledge as being related to exotic fruits, but it does not include the additional detail about the family liking to try new exotic fruits every week.
# 2. The actual response correctly categorizes the new knowledge as a "Like".
# 3. The actual response incorrectly suggests to create the knowledge, while the expected response indicates that the action should be to delete the existing knowledge.
# Encountered 3 bad responses. Ending process.
# {'TP': 1, 'FP': 1, 'TN': 2, 'FN': 2}
# Accuracy:  0.5
# Test complete. Accuracy: 0.5
# {'TP': 1, 'FP': 1, 'TN': 2, 'FN': 2}
# Rejected change
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 18
#       6 from graphs.prompt_writer_graph import app
#       8 input = {
#       9     "prompt": {
#      10         "opener": OPENER,
#    (...)
#      15     "messages": [],
#      16 }
# ---> 18 for output in app.with_config(
#      19     {"run_name": "Prompt Writer - Test Agent", "recursion_limit": 100}
#      20 ).stream(input):
#      21     # stream() yields dictionaries with output keyed by node name
#      22     for key, value in output.items():
#      23         print(f"Output from node '{key}':")
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain_core/runnables/base.py:4394, in RunnableBindingBase.stream(self, input, config, **kwargs)
#    4388 def stream(
#    4389     self,
#    4390     input: Input,
#    4391     config: Optional[RunnableConfig] = None,
#    4392     **kwargs: Optional[Any],
#    4393 ) -> Iterator[Output]:
# -> 4394     yield from self.bound.stream(
#    4395         input,
#    4396         self._merge_configs(config),
#    4397         **{**self.kwargs, **kwargs},
#    4398     )
#
# File ~/anaconda3/lib/python3.11/site-packages/langgraph/pregel/__init__.py:617, in Pregel.transform(self, input, config, output_keys, input_keys, **kwargs)
#     608 def transform(
#     609     self,
#     610     input: Iterator[Union[dict[str, Any], Any]],
#    (...)
#     615     **kwargs: Any,
#     616 ) -> Iterator[Union[dict[str, Any], Any]]:
# --> 617     for chunk in self._transform_stream_with_config(
#     618         input,
#     619         self._transform,
#     620         config,
#     621         output_keys=output_keys,
#     622         input_keys=input_keys,
#     623         **kwargs,
#     624     ):
#     625         yield chunk
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain_core/runnables/base.py:1656, in Runnable._transform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    1654 try:
#    1655     while True:
# -> 1656         chunk: Output = context.run(next, iterator)  # type: ignore
#    1657         yield chunk
#    1658         if final_output_supported:
#
# File ~/anaconda3/lib/python3.11/site-packages/langgraph/pregel/__init__.py:348, in Pregel._transform(self, input, run_manager, config, input_keys, output_keys, interrupt)
#     341 futures = [
#     342     executor.submit(proc.invoke, input, config)
#     343     for proc, input, config in tasks_w_config
#     344 ]
#     346 # execute tasks, and wait for one to fail or all to finish.
#     347 # each task is independent from all other concurrent tasks
# --> 348 done, inflight = concurrent.futures.wait(
#     349     futures,
#     350     return_when=concurrent.futures.FIRST_EXCEPTION,
#     351     timeout=self.step_timeout,
#     352 )
#     354 # interrupt on failure or timeout
#     355 _interrupt_or_proceed(done, inflight, step)
#
# File ~/anaconda3/lib/python3.11/concurrent/futures/_base.py:305, in wait(fs, timeout, return_when)
#     301         return DoneAndNotDoneFutures(done, not_done)
#     303     waiter = _create_and_install_waiters(fs, return_when)
# --> 305 waiter.event.wait(timeout)
#     306 for f in fs:
#     307     with f._condition:
#
# File ~/anaconda3/lib/python3.11/threading.py:622, in Event.wait(self, timeout)
#     620 signaled = self._flag
#     621 if not signaled:
# --> 622     signaled = self._cond.wait(timeout)
#     623 return signaled
#
# File ~/anaconda3/lib/python3.11/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:
